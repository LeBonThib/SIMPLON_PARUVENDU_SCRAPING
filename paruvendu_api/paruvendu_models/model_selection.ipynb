# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import json

# %%
custom_colours = ['#74a09e','#98e2c6','#f2a553','#c14953']
sns.set_theme(style="whitegrid",palette=custom_colours)

# %% [markdown]
# #### Loading the dataset

# %%
data = []
with open('../paruvendu_api/outputs/data_harvest.json','r') as sample:
    for line in sample:
        data.append(json.loads(line.strip()))
df = pd.DataFrame.from_dict(data)

# %%
df.head()
# Out:
#                                                  url  status  \
# 0  https://www.paruvendu.fr/a/voiture-occasion/ci...     200
# 1  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 2  https://www.paruvendu.fr/a/voiture-occasion/mi...     200
# 3  https://www.paruvendu.fr/a/voiture-occasion/da...     200
# 4  https://www.paruvendu.fr/a/voiture-occasion/da...     200
#
#                    location                                   version  \
# 0   le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1              68000 colmar   version 1.5 d 116 cooper pack chili bva
# 2           chorges (05230)            version mini 1.6i - 120 cooper
# 3            liévin (62800)  version duster blue dci 115 4x2 prestige
# 4  clermont-ferrand (63100)    version duster dci 110 4x4 black touch
#
#            price                                               year  \
# 0  prix 11 000 €  année novembre 2015 le comparateur d'assurance...
# ...

# %%
df.drop(['url','status','warranty','control','door_nb','seat_nb'], axis=1)
# Out:
#                        location                                   version  \
# 0       le thuit-signol (27370)          version ds3 puretech 82 bvm chic
# 1                  68000 colmar   version 1.5 d 116 cooper pack chili bva
# 2               chorges (05230)            version mini 1.6i - 120 cooper
# 3                liévin (62800)  version duster blue dci 115 4x2 prestige
# 4      clermont-ferrand (63100)    version duster dci 110 4x4 black touch
# ...                         ...                                       ...
# 8264            66000 perpignan                  version panda 1.2 8v gpl
# 8265                 81000 albi     version 1.3 multijet 16v 95ch s&s 4x4
# 8266               64420 nousty      version panda my 1.2 8v 69 ch mylife
# 8267            95200 sarcelles                version 1.2 8v eco dynamic
# 8268  34430 saint-jean-de-védas                          version easy ess
#
#               price                                               year  \
# ...
